# %%
import requests
import json
import pandas as pd
from IPython.display import Image

# %%
url = "https://www.goodreads.com/api"
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
def getFromGB(searchwords):
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn{searchwords}"
    res = requests.get(url)
    print(res.url)
    return res.json()
getFromGB("novel")
# Out:
# https://www.googleapis.com/books/v1/volumes?q=isbnnovel
# {'kind': 'books#volumes',
#  'totalItems': 174,
#  'items': [{'kind': 'books#volume',
#    'id': 'tMpADwAAQBAJ',
#    'etag': 'V/PrECOA6u8',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/tMpADwAAQBAJ',
#    'volumeInfo': {'title': 'La bailarina de Auschwitz',
#     'subtitle': 'Una inspiradora historia de valentía y supervivencia',
#     'authors': ['Edith Eger'],
#     'publisher': 'Editorial Planeta',
#     'publishedDate': '2018-01-16',
#     'description': 'Eger tenía dieciséis años cuando los nazis invadieron su pueblo de Hungría y se la llevaron con el resto de su familia a Auschwitz. Al pisar el campo, sus padres fueron enviados a la cámara de gas y ella permaneció junto a su hermana, pendiente de una muerte segura. Pero bailar El Danubio azul para Mengele salvó su vida, y a partir de entonces empezó una nueva lucha por la supervivencia. Primero en los campos de exterminio, luego en la Checoslovaquia tomada por los comunistas y, finalmente, en Estados Unidos, donde acabaría convirtiéndose en discípula de Viktor Frankl. Fue en ese momento, tras décadas ocultando su pasado, cuando se dio cuenta de la necesidad de curar sus heridas, de hablar del horror que había vivido y de perdonar como camino a la sanación. Su mensaje es claro: tenemos la capacidad de escapar de las prisiones que construimos en nuestras mentes y podemos elegir ser libres, sean cuales sean las circunstancias de nuestra vida. «Este libro es un regalo para la humanidad. Una de esas historias únicas y eternas que nunca quieres terminar de leer y que te cambian la vida para siempre.» Desmond Tutu, premio Nobel de la Paz',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9788408181637'},
#      {'type': 'ISBN_10', 'identifier': '8408181637'}],
#     'readingModes': {'text': True, 'image': True},
#     'printType': 'BOOK',
#     'categories': ['Fiction'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.7.7.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=tMpADwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=tMpADwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'es',
#     'previewLink': 'http://books.google.es/books?id=tMpADwAAQBAJ&printsec=frontcover&dq=isbnnovel&hl=&cd=1&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=tMpADwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=tMpADwAAQBAJ'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 7.49, 'currencyCode': 'EUR'},
#     'retailPrice': {'amount': 7.12, 'currencyCode': 'EUR'},
#     'buyLink': 'https://play.google.com/store/books/details?id=tMpADwAAQBAJ&rdid=book-tMpADwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 7490000, 'currencyCode': 'EUR'},
#       'retailPrice': {'amountInMicros': 7120000, 'currencyCode': 'EUR'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.es/books/download/La_bailarina_de_Auschwitz-sample-epub.acsm?id=tMpADwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.es/books/download/La_bailarina_de_Auschwitz-sample-pdf.acsm?id=tMpADwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=tMpADwAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Eger tenía dieciséis años cuando los nazis invadieron su pueblo de Hungría y se la llevaron con el resto de su familia a Auschwitz.'}},
#   {'kind': 'books#volume',
#    'id': 'GXbsDQAAQBAJ',
#    'etag': 'roUHMwYh8Zs',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/GXbsDQAAQBAJ',
#    'volumeInfo': {'title': 'The Everything Large-Print Crossword Dictionary',
#     'subtitle': 'Finding a solution has never been easier!',
#     'authors': ['Charles Timmerman'],
#     'publisher': 'Simon and Schuster',
#     'publishedDate': '2010-03-18',
#     'description': "Even the best crossword puzzlers need a little help sometimes. And if you prefer your puzzles in large print, here's a crossword dictionary you don't need a magnifying glass to read! This easy-to-read dictionary is your ultimate resource for those tricky crossword dilemmas. It's packed to the brim with more than 60,000 answer words compiled by puzzlemaster Charles Timmerman. Featuring a range of entries, including: Contradict 4 deny 5 belie, rebut 6 negate, refute Cow chow 3 hay 4 feed 5 grass Football official 3 ref 8 linesman Nervous 4 edgy 5 goosy, tense 6 onedge, uneasy 9 illatease Literary governess 4 eyre Peeved 4 ired, sore 5 angry, cross 6 inapet 8 upinarms Remove 4 dele, doff, oust 5 erase, evict 8 takeaway Shakespearean forest 5 arden You won't miss a word--from the common to the complex--with The Everything Large-Print Crossword Dictionary. It's the perfect large-print crossword companion.",
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781605507477'},
#      {'type': 'ISBN_10', 'identifier': '1605507474'}],
#     'readingModes': {'text': True, 'image': False},
#     'pageCount': 752,
#     'printType': 'BOOK',
#     'categories': ['Games & Activities'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.3.2.0.preview.2',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=GXbsDQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=GXbsDQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.es/books?id=GXbsDQAAQBAJ&pg=PA734&dq=isbnnovel&hl=&cd=2&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=GXbsDQAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=GXbsDQAAQBAJ'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 12.8, 'currencyCode': 'EUR'},
#     'retailPrice': {'amount': 12.8, 'currencyCode': 'EUR'},
#     'buyLink': 'https://play.google.com/store/books/details?id=GXbsDQAAQBAJ&rdid=book-GXbsDQAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 12800000, 'currencyCode': 'EUR'},
#       'retailPrice': {'amountInMicros': 12800000, 'currencyCode': 'EUR'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.es/books/download/The_Everything_Large_Print_Crossword_Dic-sample-epub.acsm?id=GXbsDQAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=GXbsDQAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': '3 ast Nova, e.g. 3 lox Novel 3 new 5 fresh Novel ending 4ette 6 epilog Novel ID 4 <br>\n<b>isbn Novel</b> idea 4 plot 5 story Novel plantation 4 tara Novel subtitled “APeep at <br>\nPolynesian Life” 5 typee Novelist ___ Mae Brown 4 rita Novelist Bagnold 4enid&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': '2M1CDwAAQBAJ',
#    'etag': 'NksSiu2m7g4',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/2M1CDwAAQBAJ',
#    'volumeInfo': {'title': 'Focus On: 100 Most Popular Fictional African-American People',
#     'authors': ['Wikipedia contributors'],
#     'publisher': 'e-artnow sro',
#     'readingModes': {'text': True, 'image': True},
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '1.1.1.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=2M1CDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=2M1CDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.es/books?id=2M1CDwAAQBAJ&pg=PT583&dq=isbnnovel&hl=&cd=3&source=gbs_api',
#     'infoLink': 'http://books.google.es/books?id=2M1CDwAAQBAJ&dq=isbnnovel&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Focus_On_100_Most_Popular_Fictional_Afri.html?hl=&id=2M1CDwAAQBAJ'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.es/books/download/Focus_On_100_Most_Popular_Fictional_Afri-sample-epub.acsm?id=2M1CDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=2M1CDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Matthew Woodring Stover, George Lucas, <b>ISBN (novel</b>), Shatterpoint 1st edition, <br>\n2003. Matthew Woodring Stover, ISBN The New Essential Guide to Characters, <br>\n1st edition, 2002. Daniel Wallace, Michael Sutfin, ISBN Star Wars: The Phantom&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': '9mIhvxShVGAC',
#    'etag': 'CWBUTt18pL0',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/9mIhvxShVGAC',
#    'volumeInfo': {'title': 'DeaLova',
#     'authors': ['Dyan Nuranindya'],
#     'publisher': 'Gramedia Pustaka Utama',
#     'publishedDate': '2006',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '9792207600'},
#      {'type': 'ISBN_13', 'identifier': '9789792207606'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 302,
#     'printType': 'BOOK',
#     'categories': ['Young adult fiction'],
#     'averageRating': 4.5,
#     'ratingsCount': 19,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.1.2.0.preview.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=9mIhvxShVGAC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=9mIhvxShVGAC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'id',
#     'previewLink': 'http://books.google.es/books?id=9mIhvxShVGAC&pg=PA5&dq=isbnnovel&hl=&cd=4&source=gbs_api',
#     'infoLink': 'http://books.google.es/books?id=9mIhvxShVGAC&dq=isbnnovel&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/DeaLova.html?hl=&id=9mIhvxShVGAC'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=9mIhvxShVGAC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False}},
#   {'kind': 'books#volume',
#    'id': '-vHfAAAAMAAJ',
#    'etag': 'j7MEliMd3fs',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/-vHfAAAAMAAJ',
#    'volumeInfo': {'title': 'Those who Were There',
#     'subtitle': 'Eyewitness Accounts of the War in Southeast Asia, 1956-1975 & Aftermath : Annotated Bibliography of Books, Articles & Topic-related Magazines, Covering Writings Both Factual & Imaginative',
#     'authors': ['Merritt Clifton'],
#     'publisher': 'Dustbooks',
#     'publishedDate': '1984',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'UOM:39015011001545'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 297,
#     'printType': 'BOOK',
#     'categories': ['Biography & Autobiography'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.0.1.0.preview.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=-vHfAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=-vHfAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.es/books?id=-vHfAAAAMAAJ&q=isbnnovel&dq=isbnnovel&hl=&cd=5&source=gbs_api',
#     'infoLink': 'http://books.google.es/books?id=-vHfAAAAMAAJ&dq=isbnnovel&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Those_who_Were_There.html?hl=&id=-vHfAAAAMAAJ'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=-vHfAAAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': '154 pages , perfect - bound paper , 594 x 8 , no LCC or <b>ISBN . Novel</b> . Author was <br>\na first lieutenant with the 25th Division in Vietnam , 1967 - 68 . Protagonist of this <br>\nnovel is a Navajo Indian and Vietnam veteran struggling against racism&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'FV18DLfHz0MC',
#    'etag': 'NIJ9tYuIlho',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/FV18DLfHz0MC',
#    'volumeInfo': {'title': 'Edensor',
#     'subtitle': 'Tetralogi Laskar Pelangi',
#     'authors': ['Andrea Hirata'],
#     'publisher': 'Bentang Pustaka',
#     'publishedDate': '2007-01-01',
#     'description': 'Novel ketiga dari tetralogi Laskar Pelangi ini bercerita tentang petualangan Ikal dan Arai di Eropa. Setelah berhasil memperoleh beasiswa ke Prancis, Ikal dan Arai, mengalami banyak kejadian yang orang biasa sebut sebagai kejutan budaya. Banyak kebiasaan dan peradaban Eropa yang berlainan sama sekali dengan peradaban yang selama ini mereka pahami sebagai orang Indonesia,khususnya Melayu. Di dalam buku ini juga Ikal dan Arai kembali menuai karma akibat kenakalan-kenalan yang pernah mereka lakukan semasa kecil dan remaja dulu. Pembaca akan dibawa ke dalam petualangan mereka menyusuri Eropa dengan berbagai pengalaman yang mencengangkan, mencekam, membuat terbahak, sekaligus berurai air mata. Aku ingin mendaki puncak tantangan, menerjang batu granit kesulitan, menggoda mara bahaya, dan memecahkan misteri dengan sains. Aku ingin menghirup berupa-rupa pengalaman lalu terjun bebas menyelami labirin lika-liku hidup yang ujungnya tak dapat disangka. Aku mendamba kehidupan dengan kemungkinan-kemungkinan yang bereaksi satu sama lain seperti benturan molekul uranium: meletup tak terduga-duga, menyerap, mengikat, mengganda, berkembang, terurai, dan berpencar ke arah yang mengejutkan. Aku ingin ke tempat-tempat yang jauh, menjumpai beragam bahasa dan orang-orang asing. Aku ingin berkelana, menemukan arahku dengan membaca bintang gemintang. Aku ingin mengarungi padang dan gurun-gurun, ingin melepuh terbakar matahari, limbung dihantam angin, dan menciut dicengkeram dingin. Aku ingin kehidupan yang menggetarkan, penuh dengan penaklukan. Aku ingin hidup! Ingin merasakan sari pati hidup! Novel ini kian meneguhkan kehadiran tetralogi Laskar Pelangi sebagai karya unggul yang pasti disukai pembaca. —Ahmad Tohari, sastrawan Andrea Hirata membuatku mabuk kepayang!—Linda Christanty, cerpenis Berpotensi memberikan letupan inspirasi bagi pembacanya.—Tabloid Wanita Indonesia [Bentang, Motivasi, Inspirasi, Novel, Indonesia]',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '9791227020'},
#      {'type': 'ISBN_13', 'identifier': '9789791227025'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 288,
#     'printType': 'BOOK',
#     'categories': ['Indonesian fiction'],
#     'averageRating': 4,
#     'ratingsCount': 75,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.1.2.0.preview.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=FV18DLfHz0MC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=FV18DLfHz0MC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'id',
#     'previewLink': 'http://books.google.es/books?id=FV18DLfHz0MC&pg=PA293&dq=isbnnovel&hl=&cd=6&source=gbs_api',
#     'infoLink': 'http://books.google.es/books?id=FV18DLfHz0MC&dq=isbnnovel&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Edensor.html?hl=&id=FV18DLfHz0MC'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=FV18DLfHz0MC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False}},
#   {'kind': 'books#volume',
#    'id': 'rzxVAAAAYAAJ',
#    'etag': 'yAO/hqNkD2U',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/rzxVAAAAYAAJ',
#    'volumeInfo': {'title': 'Library Journal',
#     'publishedDate': '1972',
#     'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'UVA:X000018196'}],
#     'readingModes': {'text': False, 'image': False},
#     'printType': 'BOOK',
#     'categories': ['Libraries'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.11.2.0.preview.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=rzxVAAAAYAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=rzxVAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.es/books?id=rzxVAAAAYAAJ&q=isbnnovel&dq=isbnnovel&hl=&cd=7&source=gbs_api',
#     'infoLink': 'http://books.google.es/books?id=rzxVAAAAYAAJ&dq=isbnnovel&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Library_Journal.html?hl=&id=rzxVAAAAYAAJ'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=rzxVAAAAYAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': '<b>ISBN novel</b> reads quickly . Susan Beth Pfefscene ( Cambridge ) to the promised <br>\nland 0-8128-1510-6 . LC 72-80346 . fer , Department of Women , Orange of the <br>\nWest ( Anahita Island ) in 1966 , In this delightfully ironic novel of con County&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': '3M9WDwAAQBAJ',
#    'etag': 'Z0DyTkR1uhY',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/3M9WDwAAQBAJ',
#    'volumeInfo': {'title': 'If Only',
#     'authors': ['Innayah Putri'],
#     'publisher': 'Bentang Belia',
#     'publishedDate': '2018-04-26',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9786024302689'},
#      {'type': 'ISBN_10', 'identifier': '6024302681'}],
#     'readingModes': {'text': True, 'image': False},
#     'pageCount': 400,
#     'printType': 'BOOK',
#     'categories': ['Fiction'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '2.2.3.0.preview.2',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=3M9WDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=3M9WDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'id',
#     'previewLink': 'http://books.google.es/books?id=3M9WDwAAQBAJ&printsec=frontcover&dq=isbnnovel&hl=&cd=8&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=3M9WDwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=3M9WDwAAQBAJ'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 3.28, 'currencyCode': 'EUR'},
#     'retailPrice': {'amount': 3.12, 'currencyCode': 'EUR'},
#     'buyLink': 'https://play.google.com/store/books/details?id=3M9WDwAAQBAJ&rdid=book-3M9WDwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 3280000, 'currencyCode': 'EUR'},
#       'retailPrice': {'amountInMicros': 3120000, 'currencyCode': 'EUR'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.es/books/download/If_Only-sample-epub.acsm?id=3M9WDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=3M9WDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False}},
#   {'kind': 'books#volume',
#    'id': 'FRUUAQAAMAAJ',
#    'etag': 'JdSDrujVUZs',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/FRUUAQAAMAAJ',
#    'volumeInfo': {'title': 'A Pocketful of Goobers, a Story about George Washington Carver by Barabara Mitchell',
#     'subtitle': 'Teacher Guide',
#     'authors': ['Jean Jamieson'],
#     'publisher': 'Novel Units, Incorporated',
#     'publishedDate': '1994',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'PSU:000049166514'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 42,
#     'printType': 'BOOK',
#     'categories': ["Children's literature"],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.0.2.0.preview.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=FRUUAQAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=FRUUAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.es/books?id=FRUUAQAAMAAJ&pg=PT2&dq=isbnnovel&hl=&cd=9&source=gbs_api',
#     'infoLink': 'http://books.google.es/books?id=FRUUAQAAMAAJ&dq=isbnnovel&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/A_Pocketful_of_Goobers_a_Story_about_Geo.html?hl=&id=FRUUAQAAMAAJ'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=FRUUAQAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False}},
#   {'kind': 'books#volume',
#    'id': '6hXhAAAAMAAJ',
#    'etag': 'GffMHI69fqc',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/6hXhAAAAMAAJ',
#    'volumeInfo': {'title': 'The Library Journal',
#     'subtitle': 'Chiefly Devoted to Library Economy and Bibliography',
#     'publishedDate': '1993-04',
#     'description': 'Includes, beginning Sept. 15, 1954 (and on the 15th of each month, Sept.-May) a special section: School library journal, ISSN 0000-0035, (called Junior libraries, 1954-May 1961). Also issued separately.',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'UOM:39015082964407'}],
#     'readingModes': {'text': False, 'image': False},
#     'printType': 'BOOK',
#     'categories': ['Libraries'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '1.14.4.0.preview.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=6hXhAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=6hXhAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.es/books?id=6hXhAAAAMAAJ&q=isbnnovel&dq=isbnnovel&hl=&cd=10&source=gbs_api',
#     'infoLink': 'http://books.google.es/books?id=6hXhAAAAMAAJ&dq=isbnnovel&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/The_Library_Journal.html?hl=&id=6hXhAAAAMAAJ'},
#    'saleInfo': {'country': 'ES',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'ES',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=6hXhAAAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': '<b>ISBN novel</b> ( following Secrets , LJ 2 / 1 / 92 , and ing ways . Her lyrical chapters <br>\nare gems 1 - 878685 - 38 - 4 . $ 19 . 95 . F Heart &#39; s Desires , LJ 1 / 91 ) , creating <br>\nbeliev - glinting with humor that could generally Nora Holing was orphaned&nbsp;...'}}]}

# %% [markdown]
# ## API

# %%
def get_info (isbn):
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"
    res = requests.get(url).json()
    description = res["items"][0]["volumeInfo"]["description"]
    pages = res["items"][0]["volumeInfo"]["pageCount"]
    image = display(Image(url=res["items"][0]["volumeInfo"]["imageLinks"]["smallThumbnail"]))
    sales = res["items"][0]["saleInfo"]["isEbook"]
    
    return description, pages, image, sales
    #print(url)
    
get_info("0735619670")
# Out:
# <img src="http://books.google.com/books/content?id=pDsFCAAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
# ('Features the best practices in the art and science of constructing software--topics include design, applying good techniques to construction, eliminating errors, planning, managing construction activities, and relating personal character to superior software. Original. (Intermediate)',
#  914,
#  None,
#  False)

# %%
def get_description (isbn):
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"
    res = requests.get(url).json()
    return res["items"][0]["volumeInfo"]["description"]
    print(url)
    
x = get_description("0735619670")
x
# Out:
# 'Features the best practices in the art and science of constructing software--topics include design, applying good techniques to construction, eliminating errors, planning, managing construction activities, and relating personal character to superior software. Original. (Intermediate)'

# %%
import os
from dotenv import load_dotenv
load_dotenv()

def getFromGA(searchwords, queryParams={}):
    url = f"https://www.googleapis.com/books/v1/volumes?q={searchwords}&key=AIzaSyBr_5sdn9AKCx4Ptlwgbb7dIwojyiEOIdI"
    res = requests.get(url, params=queryParams)
    print(res.url)
    return res.json()

# %%
url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:0735619670"
res = requests.get(url).json()
print(url)
description =res["items"][0]["volumeInfo"]["description"]
# Out:
# https://www.googleapis.com/books/v1/volumes?q=isbn:0735619670

# %% [markdown]
# ### Segunda Parte

# %%
result = pd.read_csv("Output/books_output.csv")
result = pd.DataFrame(result)
result.head(5).sort_values(by="year", ascending=False)

# %%
def output(x,y):
    return result[(result["year"]== x) & (result["categories"].str.contains(f"{y}"))& (result["rating-avg"]>4)].sort_values(by="rating-avg",ascending=False).head(1)

# %%
z = output(2009.0, 3100)
z

# %%
pd.unique(z["isbn10"]).tolist()

# %%
z.reset_index()

# %%
#y = z[z["isbn10"]]

#z.loc[0,["isbn10"]]
y = pd.unique(z["isbn10"]).tolist()
y

# %% [markdown]
# # funcion buena

# %%
def get_description(x):
    
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{x}"
    res = requests.get(url).json()
    return res["items"][0]["volumeInfo"]["description"]
    print(res.url)
get_description("178919430X")

# %%
x = pd.unique(z["isbn10"]).tolist()

def get_description(x):
    
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{x}"
    res = requests.get(url).json()
    return res["items"][0]["volumeInfo"]["description"]
    print(res.url)
results = [get_description(i) for i in x]

results

# %%
url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:1782216952"
res = requests.get(url).json()
title = res["items"][0]["volumeInfo"]["title"]
author = res["items"][0]["volumeInfo"]["authors"][0]
author

# %%
x = pd.unique(z["isbn10"]).tolist()

def get_info (x):
    
    try: 
        url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{x}"
        res = requests.get(url).json()
        title = res["items"][0]["volumeInfo"]["title"]
        author = res["items"][0]["volumeInfo"]["authors"][0]
        description = res["items"][0]["volumeInfo"]["description"]
        pages = res["items"][0]["volumeInfo"]["pageCount"]
        image = display(Image(url=res["items"][0]["volumeInfo"]["imageLinks"]["smallThumbnail"]))
        sales = res["items"][0]["saleInfo"]["isEbook"]
        return description, pages, image, sales
    except KeyError:
        return "Sin descripción"
    #print(url)
    
get_info("1782216952")

# %%
def lista(x):
    return z["isbn10"].tolist()

x = z["isbn10"].tolist()

def get_info(x):   
    url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{x}"
    res = requests.get(url).json()
    description = res["items"][0]["volumeInfo"]["description"]
    pages = res["items"][0]["volumeInfo"]["pageCount"]
    image = display(Image(url=res["items"][0]["volumeInfo"]["imageLinks"]["smallThumbnail"]))
    sales = res["items"][0]["saleInfo"]["isEbook"]
    return description, pages, image, sales

list(['9780007284993'])

# %%
from reportlab.pdfgen import canvas

fileName ="My book report"
documentTitle= "Bestselleres report"
title = "Your book report"

textlines = "output"

pdf = canvas.Canvas("filename")
pdf.save()
#https://www.youtube.com/watch?v=ZDR7-iSuwkQ

# %% [markdown]
# ### web scrapping

# %%
from bs4 import BeautifulSoup

html = requests.get("https://www.buzzfeednews.com/article/ariannarebolini/winners-goodreads-best-books-2019").text
soup = BeautifulSoup(html)
soup

# %%
titles = soup.select("h2")
titles[1].text
titles[2].text
titles[3].text
titles[4].text

# %%
titles = soup.select("h2")
[ titles[1].text for i in titles]

# %%
url = 'https://www.buzzfeednews.com/article/ariannarebolini/winners-goodreads-best-books-2019'
title = requests.get(url)
title

import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
