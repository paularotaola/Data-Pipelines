# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd
import numpy as np
import re

# %%
result = pd.read_csv("Input/dataset-books.csv")
df = pd.DataFrame(result)
df.head(3)
# Out:
#   authors bestsellers-rank                                   categories  \
# 0     [1]              NaN  [334, 335, 341, 2622, 352, 2626, 353, 2627]
# 1     [2]            67532  [376, 378, 868, 873, 900, 2771, 3097, 2590]
# 2  [3, 4]           150327                                 [2978, 2980]
#
#                                          description  dimension-x  \
# 0  Renowned urban artist Shepard Fairey's new loo...        111.0
# 1  These 100 skills, adapted for civilians from a...        140.0
# 2  The world is full of pointless things. From ra...        193.0
#
#    dimension-y  dimension-z edition edition-statement for-ages  ...  \
# 0        181.0         20.0     NaN             Repr.      NaN  ...
# 1        210.0         18.0     NaN               NaN      NaN  ...
# 2        197.0         21.0     NaN               NaN      NaN  ...
#
#        isbn10        isbn13 lang publication-date publication-place  \
# 0   141036141  9.780141e+12   en       2008-10-01               1.0
# 1  1501143905  9.781501e+12   en       2016-11-16               2.0
# 2  1444762052  9.781445e+12   en       2013-05-23               1.0
#
#   rating-avg  rating-count                                              title  \
# 0       4.18     2918204.0                                               1984
# 1       4.01         425.0  100 Deadly Skills: Survival Edition : The SEAL...
# 2       3.59         539.0  The 100 Most Pointless Things in the World : A...
#
#                                                  url  weight
# 0                  /1984-George-Orwell/9780141036144   184.0
# 1  /100-Deadly-Skills-Survival-Edition-Clint-Emer...   367.0
# 2  /100-Most-Pointless-Things-World-Alexander-Arm...   220.0
#
# [3 rows x 25 columns]

# %% [markdown]
# ### 1. Analizamos el dataset de libros

# %%
# Eliminamos las columnas que no necesitamos

drop_cols = ['id','bestsellers-rank','dimension-x','edition','edition-statement', 'for-ages', 'format', 'illustrations-note',
       'imprint', 'index-date', 'dimension-y',"isbn13",'publication-place','dimension-z','weight','rating-count','url']
df = df.drop(drop_cols, axis =1)
df.head(5)
# Out:
#   authors                                   categories  \
# 0     [1]  [334, 335, 341, 2622, 352, 2626, 353, 2627]
# 1     [2]  [376, 378, 868, 873, 900, 2771, 3097, 2590]
# 2  [3, 4]                                 [2978, 2980]
# 3     [5]                                 [2948, 2953]
# 4     [6]                           [2942, 2948, 2953]
#
#                                          description      isbn10 lang  \
# 0  Renowned urban artist Shepard Fairey's new loo...   141036141   en
# 1  These 100 skills, adapted for civilians from a...  1501143905   en
# 2  The world is full of pointless things. From ra...  1444762052   en
# 3  Delight children and adults alike by creating ...  1784943460   en
# 4  Make your own collection of irresistibly cute ...  1782216952   en
#
#   publication-date  rating-avg  \
# 0       2008-10-01        4.18
# 1       2016-11-16        4.01
# 2       2013-05-23        3.59
# 3       2017-11-14        3.66
# 4       2019-06-04        4.66
#
#                                                title
# 0                                               1984
# 1  100 Deadly Skills: Survival Edition : The SEAL...
# 2  The 100 Most Pointless Things in the World : A...
# 3                                   50 Knitted Dolls
# 4                            20 to Knit: Pocket Pets

# %%
# Vemos los data types
df.dtypes
# Out:
# authors              object
# categories           object
# description          object
# isbn10               object
# lang                 object
# publication-date     object
# rating-avg          float64
# title                object
# dtype: object

# %%
# Analizamos valores nulos

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# authors - 0.0%
# categories - 0.0%
# description - 7.0%
# isbn10 - 0.0%
# lang - 5.0%
# publication-date - 0.0%
# rating-avg - 64.0%
# title - 0.0%

# %%
null_cols = df.isnull().sum()
null_cols
# Out:
# authors                 0
# categories              0
# description          4022
# isbn10                  0
# lang                 2851
# publication-date      139
# rating-avg          35990
# title                   0
# dtype: int64

# %%
# Modificamos la columna de "publication-date" formato fecha y sacamos el año de la fecha

df["publication-date"] = pd.to_datetime(df["publication-date"])
df["year"] = pd.DatetimeIndex(df["publication-date"]).year

# %%
# Eliminamos las columnas sin años ya que es un campo necesario a la hora de filtrar
df = df.dropna(subset=['year'])

# %%
# Arregalamos la columna "year"
df["year"] =  df["year"].apply(lambda x: int(x))
df.head(3)
# Out:
#   authors                                   categories  \
# 0     [1]  [334, 335, 341, 2622, 352, 2626, 353, 2627]
# 1     [2]  [376, 378, 868, 873, 900, 2771, 3097, 2590]
# 2  [3, 4]                                 [2978, 2980]
#
#                                          description      isbn10 lang  \
# 0  Renowned urban artist Shepard Fairey's new loo...   141036141   en
# 1  These 100 skills, adapted for civilians from a...  1501143905   en
# 2  The world is full of pointless things. From ra...  1444762052   en
#
#   publication-date  rating-avg  \
# 0       2008-10-01        4.18
# 1       2016-11-16        4.01
# 2       2013-05-23        3.59
#
#                                                title  year
# 0                                               1984  2008
# 1  100 Deadly Skills: Survival Edition : The SEAL...  2016
# 2  The 100 Most Pointless Things in the World : A...  2013

# %%
# Finalmente eliminamos la columna de fecha de publicación y autor
drop_cols = ['publication-date', 'authors']
df = df.drop(drop_cols, axis =1)

# %%
df.head(5)
# Out:
#                                     categories  \
# 0  [334, 335, 341, 2622, 352, 2626, 353, 2627]
# 1  [376, 378, 868, 873, 900, 2771, 3097, 2590]
# 2                                 [2978, 2980]
# 3                                 [2948, 2953]
# 4                           [2942, 2948, 2953]
#
#                                          description      isbn10 lang  \
# 0  Renowned urban artist Shepard Fairey's new loo...   141036141   en
# 1  These 100 skills, adapted for civilians from a...  1501143905   en
# 2  The world is full of pointless things. From ra...  1444762052   en
# 3  Delight children and adults alike by creating ...  1784943460   en
# 4  Make your own collection of irresistibly cute ...  1782216952   en
#
#    rating-avg                                              title  year
# 0        4.18                                               1984  2008
# 1        4.01  100 Deadly Skills: Survival Edition : The SEAL...  2016
# 2        3.59  The 100 Most Pointless Things in the World : A...  2013
# 3        3.66                                   50 Knitted Dolls  2017
# 4        4.66                            20 to Knit: Pocket Pets  2019

# %% [markdown]
# ### 3. Filtrado y limpieza por géneros

# %%
# Utilizamos la función explode para asignar una fila por género literario y quitamos los caracteres especiales

# %%
df = df.assign(categories=df.categories.str.split(",")).explode('categories')

spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–"]
for char in spec_chars:
    df['categories'] = df['categories'].str.replace(char, '')

# %%
# Renombramos la columna de "categories" por "category_id" para posteriomente poder unirla con el dataset de categorias
df = df.rename(columns={'categories':'category_id'})

# %%
df.head(5)
# Out:
#   category_id                                        description     isbn10  \
# 0         334  Renowned urban artist Shepard Fairey's new loo...  141036141
# 0         335  Renowned urban artist Shepard Fairey's new loo...  141036141
# 0         341  Renowned urban artist Shepard Fairey's new loo...  141036141
# 0        2622  Renowned urban artist Shepard Fairey's new loo...  141036141
# 0         352  Renowned urban artist Shepard Fairey's new loo...  141036141
#
#   lang  rating-avg title  year
# 0   en        4.18  1984  2008
# 0   en        4.18  1984  2008
# 0   en        4.18  1984  2008
# 0   en        4.18  1984  2008
# 0   en        4.18  1984  2008

# %% [markdown]
# ### 3. Analizamos el dataset de categorias

# %%
# Analizamos el dataset de categorias
categories = pd.read_csv("Input/categories.csv")
categories.head(5)
# Out:
#    category_id                                category_name
# 0         1998                             .Net Programming
# 1          176  20th Century & Contemporary Classical Music
# 2         3291  20th Century & Contemporary Classical Music
# 3         2659      20th Century History: C 1900  To C 2000
# 4         2661          21st Century History: From C 2000 -

# %%
# Pasamos las dos columnas de category_id a int para poder unirlas. En este caso transformamos la columna del dataset de libros
df["category_id"] = df["category_id"].apply(lambda x: int(x))

# %%
# Hacemos merge de ambos dataset por category_id para poder filtrar por nombre
result = pd.merge(df, categories, on='category_id')
result.head(5)
# Out:
#    category_id                                        description      isbn10  \
# 0          334  Renowned urban artist Shepard Fairey's new loo...   141036141
# 1          334  "Richardson's Clarissa explores the subtleties...  1641813911
# 2          334                    World's Classics Deluxe Edition  1641813997
# 3          334                    World's Classics Deluxe Edition  164181599X
# 4          334  Elisabeth Matrei, fotógrafa de renombre y prot...  8498414261
#
#   lang  rating-avg                                              title  year  \
# 0   en        4.18                                               1984  2008
# 1   en         NaN  Clarissa Harlowe : Or, The History of a Young ...  2020
# 2   en        3.49                                    Nightmare Abbey  2020
# 3   en         NaN  The Mayor of Casterbridge : The Life and Death...  2020
# 4   es        3.89  Tres senderos hacia el lago / Three Paths to t...  2011
#
#           category_name
# 0  Contemporary Fiction
# 1  Contemporary Fiction
# 2  Contemporary Fiction
# 3  Contemporary Fiction
# 4  Contemporary Fiction

# %% [markdown]
# A continuación están los géneros que vamos a utilizar en este ejercicio_
#
# * Classic Books & Novels
# * poetry
# * drama
# * adventure
# * romance
# * Thrillers
# * biographies and autobiographies
# * comic
# * science fiction
# * life science
# * for kids
# * romance
# * Crime
# * Religious
# * horror
# * Historical Fiction
# * Personal Development
# * Graphic Novels: Manga
# * Guidebooks

# %%
result.head(3)
# Out:
#    category_id                                        description      isbn10  \
# 0          334  Renowned urban artist Shepard Fairey's new loo...   141036141
# 1          334  "Richardson's Clarissa explores the subtleties...  1641813911
# 2          334                    World's Classics Deluxe Edition  1641813997
#
#   lang  rating-avg                                              title  year  \
# 0   en        4.18                                               1984  2008
# 1   en         NaN  Clarissa Harlowe : Or, The History of a Young ...  2020
# 2   en        3.49                                    Nightmare Abbey  2020
#
#           category_name
# 0  Contemporary Fiction
# 1  Contemporary Fiction
# 2  Contemporary Fiction

# %%
genres = ["Classic Books & Novels", "poetry", "drama", "adventure",
"romance", "Thrillers", "biographies", "comic", "science fiction", "life science", "for kids", "romance","Crime",
"Religious","horror", "Historical Fiction", "Personal Development", "Graphic Novels: Manga","Guidebooks"
]

# %%
# Filtramos el dataset por las celdas que CONTIENEN los generos anterior (de esta forma no nos limitamos a coincidencias exactas)
# Ignoramos mayúsculas/minúsculas

result = result[result['category_name'].str.contains("Classic Books & Novels|poetry|drama|adventure|romance|Thrillers|biographies|comic|science fiction|life science|for kids|romance|Crime|Religious|horror|Historical Fiction|Personal Development|Graphic Novels: Manga|Guidebooks", regex=True,flags= re.IGNORECASE)]
result.head(5)
# Out:
#      category_id                                        description  \
# 844          335  Renowned urban artist Shepard Fairey's new loo...
# 845          335  The Marquis de Sade, vilified by respectable s...
# 846          335  The 120 Days of Sodom is the Marquis de Sade's...
# 847          335  This book is the very simple story of the love...
# 848          335  "Richardson's Clarissa explores the subtleties...
#
#          isbn10 lang  rating-avg  \
# 844   141036141   en        4.18
# 845   802130127   en        3.46
# 846    99629607   en        3.11
# 847   751503843   en        4.20
# 848  1641813911   en         NaN
#
#                                                  title  year  \
# 844                                               1984  2008
# 845           The 120 Days of Sodom and Other Writings  1994
# 846         The 120 Days Of Sodom : And Other Writings  1995
# 847                              84 Charing Cross Road  1982
# 848  Clarissa Harlowe : Or, The History of a Young ...  2020
#
#               category_name
# 844  Classic Books & Novels
# 845  Classic Books & Novels
# 846  Classic Books & Novels
# 847  Classic Books & Novels
# 848  Classic Books & Novels

# %%
# Vemos que hemos reducido considerablemente nuestro dataset
result.shape
# Out:
# (19313, 8)

# %%
# Guardamos el dataset que es con el que vamos a trabajar
result.to_csv('Output/books_clean_dataset.csv')
