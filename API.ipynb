# %%
import requests
import json

# %%
url = "https://www.goodreads.com/api"
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
import os
from dotenv import load_dotenv
load_dotenv()

def getFromGR(endpoint, queryParams={}):
    url = f"https://www.goodreads.com/api{endpoint}"

    apiKey = os.getenv("GOODREADS_APIKEY")
    if not apiKey:
        raise ValueError("Please setup the GOODREADS_APIKEY env variable")
    headers = {
        "Authorization": f"token {apiKey}"
    }
    
    res = requests.get(url, headers=headers, params=queryParams)
    print(res.url)
    return res.json()

# %%
import os
from dotenv import load_dotenv
load_dotenv()

def getFromGR(endpoint, queryParams={}):
    url = f"https://www.goodreads.com/api{endpoint}"

    apiKey = os.getenv("GOODREADS_APIKEY")
    secretKey = os.getenv("GOODREADS_SECRETKEY")
    if not apiKey:
        raise ValueError("Please setup the GOODREADS_APIKEY env variable")
    if not secretKey:
        raise ValueError("Please setup the GOODREADS_SECRETKEY env variable")   
    headers = {
        "Authorization": f"token {apiKey}",
        "Authorization": f"token {secretKey}"
    }
    
    res = requests.get(url, headers=headers, params=queryParams)
    print(res.url)
    return res.json()

# %%
#getFromGR("/list/show/146534.Florence_Williams_Books_to_Transport_You_to_Wild_Open_Spaces")

# %%
h = getFromGR("/Wayne_W_Dyer/show.xml")
# Out:
# https://www.goodreads.com/api/Wayne_W_Dyer/show.xml
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-30-b516f22cfd9e> in <module>
# ----> 1 h = getFromGR("/Wayne_W_Dyer/show.xml")
#
# <ipython-input-29-33bcd1565be3> in getFromGR(endpoint, queryParams)
#      19     res = requests.get(url, headers=headers, params=queryParams)
#      20     print(res.url)
# ---> 21     return res.json()
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /opt/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
res1 = requests.get("https://api.punkapi.com/v2")
res1
# Out:
# <Response [404]>

# %%
data = res1.json()

# %%
import json
import requests
 
response = requests.get('https://jsonplaceholder.typicode.com/todos')
response
# Out:
# <Response [200]>

# %%
def getFromNY(endpoint, queryParams={}):
    url = f"https://api.nytimes.com/{endpoint}"

    apiKey = os.getenv("NY_APIKEY")
    if not apiKey:
        raise ValueError("Please setup the NY_APIKEY env variable")
    headers = {
        "Authorization": f"token {apiKey}"
    }
    
    res = requests.get(url, headers=headers, params=queryParams)
    print(res.url)
    return res.json()

# %%
getFromNY("svc/books/v3/lists/names.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-857e5846ef46> in <module>
# ----> 1 getFromNY("svc/books/v3/lists/names.json")
#
# <ipython-input-50-f11480afb7ab> in getFromNY(endpoint, queryParams)
#       4     apiKey = os.getenv("NY_APIKEY")
#       5     if not apiKey:
# ----> 6         raise ValueError("Please setup the NY_APIKEY env variable")
#       7     headers = {
#       8         "Authorization": f"token {apiKey}"
#
# ValueError: Please setup the NY_APIKEY env variable

# %%
data = res.json()
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company.  All Rights Reserved.',
#  'num_results': 15,
#  'last_modified': '2020-06-17T23:39:01-04:00',
#  'results': {'list_name': 'Hardcover Fiction',
#   'list_name_encoded': 'hardcover-fiction',
#   'bestsellers_date': '2020-06-13',
#   'published_date': '2020-06-28',
#   'published_date_description': 'latest',
#   'next_published_date': '',
#   'previous_published_date': '2020-06-21',
#   'display_name': 'Hardcover Fiction',
#   'normal_list_ends_at': 15,
#   'updated': 'WEEKLY',
#   'books': [{'rank': 1,
#     'rank_last_week': 2,
#     'weeks_on_list': 93,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0735219095',
#     'primary_isbn13': '9780735219090',
#     'publisher': 'Putnam',
#     'description': 'In a quiet town on the North Carolina coast in 1969, a young woman who survived alone in the marsh becomes a murder suspect.',
#     'price': 0,
#     'title': 'WHERE THE CRAWDADS SING',
#     'author': 'Delia Owens',
#     'contributor': 'by Delia Owens',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780735219090.jpg',
#     'book_image_width': 328,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/Where-Crawdads-Sing-Delia-Owens/dp/0735219095?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0735219095', 'isbn13': '9780735219090'},
#      {'isbn10': '0735219117', 'isbn13': '9780735219113'},
#      {'isbn10': '0525640371', 'isbn13': '9780525640370'},
#      {'isbn10': '0593105419', 'isbn13': '9780593105412'},
#      {'isbn10': '0593187989', 'isbn13': '9780593187982'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/Where-Crawdads-Sing-Delia-Owens/dp/0735219095?tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=WHERE+THE+CRAWDADS+SING&author=Delia+Owens'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780735219090'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FWHERE%2BTHE%2BCRAWDADS%2BSING%2FDelia%2BOwens%2F9780735219090'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780735219090'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780735219090?aff=NYT'}],
#     'book_uri': 'nyt://book/053b4109-4555-5aa1-9b39-cc40549bcdf0'},
#    {'rank': 2,
#     'rank_last_week': 4,
#     'weeks_on_list': 7,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0385545932',
#     'primary_isbn13': '9780385545938',
#     'publisher': 'Doubleday',
#     'description': 'The line between fact and fiction becomes blurred when an author of thrillers is found dead after a hurricane hits Camino Island.',
#     'price': 0,
#     'title': 'CAMINO WINDS',
#     'author': 'John Grisham',
#     'contributor': 'by John Grisham',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780385545938.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0385545932?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0385545932', 'isbn13': '9780385545938'},
#      {'isbn10': '0593168615', 'isbn13': '9780593168615'},
#      {'isbn10': '0593168429', 'isbn13': '9780593168424'},
#      {'isbn10': '0593215141', 'isbn13': '9780593215142'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0385545932?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=CAMINO+WINDS&author=John+Grisham'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780385545938'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FCAMINO%2BWINDS%2FJohn%2BGrisham%2F9780385545938'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780385545938'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780385545938?aff=NYT'}],
#     'book_uri': 'nyt://book/91803cda-e698-5a30-a5cf-df1a16665394'},
#    {'rank': 3,
#     'rank_last_week': 1,
#     'weeks_on_list': 2,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0525536299',
#     'primary_isbn13': '9780525536291',
#     'publisher': 'Riverhead',
#     'description': 'The lives of twin sisters who run away from a Southern black community at age 16 diverge as one returns and the other takes on a different racial identity but their fates intertwine.',
#     'price': 0,
#     'title': 'THE VANISHING HALF',
#     'author': 'Brit Bennett',
#     'contributor': 'by Brit Bennett',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780525536291.jpg',
#     'book_image_width': 331,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0525536299?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0525536299', 'isbn13': '9780525536291'},
#      {'isbn10': '0593329430', 'isbn13': '9780593329436'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0525536299?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+VANISHING+HALF&author=Brit+Bennett'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780525536291'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BVANISHING%2BHALF%2FBrit%2BBennett%2F9780525536291'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780525536291'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780525536291?aff=NYT'}],
#     'book_uri': 'nyt://book/6db17f1d-4bd0-562a-80ef-efa2a272cf64'},
#    {'rank': 4,
#     'rank_last_week': 0,
#     'weeks_on_list': 1,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0316539554',
#     'primary_isbn13': '9780316539555',
#     'publisher': 'Little, Brown',
#     'description': 'Jeremiah Cook, a veteran and former N.Y.P.D. cop, investigates a mass murder near a lake in Georgia.',
#     'price': 0,
#     'title': 'THE SUMMER HOUSE',
#     'author': 'James Patterson and Brendan DuBois',
#     'contributor': 'by James Patterson and Brendan DuBois',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780316539555.jpg',
#     'book_image_width': 320,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0316539554?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0316539554', 'isbn13': '9780316539555'},
#      {'isbn10': '0316539562', 'isbn13': '9780316539562'},
#      {'isbn10': '0316539597', 'isbn13': '9780316539593'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0316539554?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+SUMMER+HOUSE&author=James+Patterson+and+Brendan+DuBois'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780316539555'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BSUMMER%2BHOUSE%2FJames%2BPatterson%2Band%2BBrendan%2BDuBois%2F9780316539555'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780316539555'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780316539555?aff=NYT'}],
#     'book_uri': 'nyt://book/b4180d95-99e6-56a1-8ff6-440e156cd51a'},
#    {'rank': 5,
#     'rank_last_week': 0,
#     'weeks_on_list': 1,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0399179623',
#     'primary_isbn13': '9780399179624',
#     'publisher': 'Delacorte',
#     'description': 'After a California rancher‘s sudden death, his three daughters discover things they did not know about their father.',
#     'price': 0,
#     'title': "DADDY'S GIRLS",
#     'author': 'Danielle Steel',
#     'contributor': 'by Danielle Steel',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780399179624.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0399179623?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0399179623', 'isbn13': '9780399179624'},
#      {'isbn10': '0399179631', 'isbn13': '9780399179631'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0399179623?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=DADDY%27S+GIRLS&author=Danielle+Steel'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780399179624'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FDADDY%2527S%2BGIRLS%2FDanielle%2BSteel%2F9780399179624'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780399179624'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780399179624?aff=NYT'}],
#     'book_uri': 'nyt://book/3872e403-8e7a-537f-a170-e4f51dce0ef7'},
#    {'rank': 6,
#     'rank_last_week': 6,
#     'weeks_on_list': 3,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0316539422',
#     'primary_isbn13': '9780316539425',
#     'publisher': 'Little, Brown',
#     'description': 'The third book in the Jack McEvoy series. A reporter tracks a killer who uses genetic data to pick his victims.',
#     'price': 0,
#     'title': 'FAIR WARNING',
#     'author': 'Michael Connelly',
#     'contributor': 'by Michael Connelly',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780316539425.jpg',
#     'book_image_width': 322,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0316539422?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0316539422', 'isbn13': '9780316539425'},
#      {'isbn10': '0316539457', 'isbn13': '9780316539456'},
#      {'isbn10': '0316539430', 'isbn13': '9780316539432'},
#      {'isbn10': '154915706X', 'isbn13': '9781549157066'},
#      {'isbn10': '1549157043', 'isbn13': '9781549157042'},
#      {'isbn10': '1549132032', 'isbn13': '9781549132032'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0316539422?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=FAIR+WARNING&author=Michael+Connelly'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780316539425'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FFAIR%2BWARNING%2FMichael%2BConnelly%2F9780316539425'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780316539425'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780316539425?aff=NYT'}],
#     'book_uri': 'nyt://book/c959a16e-114a-5d98-af1c-7bd5a0ce5878'},
#    {'rank': 7,
#     'rank_last_week': 8,
#     'weeks_on_list': 8,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1982137975',
#     'primary_isbn13': '9781982137977',
#     'publisher': 'Scribner',
#     'description': 'Four novellas: “Mr. Harrigan’s Phone,” “The Life of Chuck,” “Rat” and “If It Bleeds.”',
#     'price': 0,
#     'title': 'IF IT BLEEDS',
#     'author': 'Stephen King',
#     'contributor': 'by Stephen King',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781982137977.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1982137975?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1982137975', 'isbn13': '9781982137977'},
#      {'isbn10': '1982137991', 'isbn13': '9781982137991'},
#      {'isbn10': '1797104799', 'isbn13': '9781797104799'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1982137975?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=IF+IT+BLEEDS&author=Stephen+King'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781982137977'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FIF%2BIT%2BBLEEDS%2FStephen%2BKing%2F9781982137977'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781982137977'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781982137977?aff=NYT'}],
#     'book_uri': 'nyt://book/ad212b13-e446-5daf-b5d9-41bef7402b4a'},
#    {'rank': 8,
#     'rank_last_week': 0,
#     'weeks_on_list': 1,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0593188063',
#     'primary_isbn13': '9780593188064',
#     'publisher': 'Putnam',
#     'description': 'When an old friend is killed during the bombing of a Barcelona cafe, Jack Ryan Jr. searches for those responsible.',
#     'price': 0,
#     'title': 'TOM CLANCY: FIRING POINT',
#     'author': 'Mike Maden',
#     'contributor': 'by Mike Maden',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780593188064.jpg',
#     'book_image_width': 331,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0593188063?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0593188063', 'isbn13': '9780593188064'},
#      {'isbn10': '059318808X', 'isbn13': '9780593188088'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0593188063?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=TOM+CLANCY%3A+FIRING+POINT&author=Mike+Maden'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780593188064'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTOM%2BCLANCY%253A%2BFIRING%2BPOINT%2FMike%2BMaden%2F9780593188064'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780593188064'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780593188064?aff=NYT'}],
#     'book_uri': 'nyt://book/ecd37109-897a-5240-bde9-d5ebf6b5de48'},
#    {'rank': 9,
#     'rank_last_week': 7,
#     'weeks_on_list': 3,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '125020710X',
#     'primary_isbn13': '9781250207104',
#     'publisher': "St. Martin's",
#     'description': 'A child star escapes her abductors, gathers herself in western Ireland and returns to Hollywood.',
#     'price': 0,
#     'title': 'HIDEAWAY',
#     'author': 'Nora Roberts',
#     'contributor': 'by Nora Roberts',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781250207104.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/125020710X?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '125020710X', 'isbn13': '9781250207104'},
#      {'isbn10': '1250207126', 'isbn13': '9781250207128'},
#      {'isbn10': '125075240X', 'isbn13': '9781250752406'},
#      {'isbn10': '1250752418', 'isbn13': '9781250752413'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/125020710X?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=HIDEAWAY&author=Nora+Roberts'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250207104'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FHIDEAWAY%2FNora%2BRoberts%2F9781250207104'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781250207104'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781250207104?aff=NYT'}],
#     'book_uri': 'nyt://book/73589940-928c-53a0-905f-59a473a5ca4e'},
#    {'rank': 10,
#     'rank_last_week': 3,
#     'weeks_on_list': 2,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0062868934',
#     'primary_isbn13': '9780062868930',
#     'publisher': 'Morrow',
#     'description': 'A wedding between a TV star and a magazine publisher on an island off the coast of Ireland turns deadly.',
#     'price': 0,
#     'title': 'THE GUEST LIST',
#     'author': 'Lucy Foley',
#     'contributor': 'by Lucy Foley',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780062868930.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0062868934?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0062868934', 'isbn13': '9780062868930'},
#      {'isbn10': '0062868950', 'isbn13': '9780062868954'},
#      {'isbn10': '006297873X', 'isbn13': '9780062978738'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0062868934?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+GUEST+LIST&author=Lucy+Foley'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780062868930'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BGUEST%2BLIST%2FLucy%2BFoley%2F9780062868930'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780062868930'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780062868930?aff=NYT'}],
#     'book_uri': 'nyt://book/dc4d32ce-1fdd-5685-946c-68fabb9dd31f'},
#    {'rank': 11,
#     'rank_last_week': 10,
#     'weeks_on_list': 8,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1538761467',
#     'primary_isbn13': '9781538761465',
#     'publisher': 'Grand Central',
#     'description': 'The sixth book in the Memory Man series. Decker and Jamison investigate a murder in a North Dakota town in a fracking boom.',
#     'price': 0,
#     'title': 'WALK THE WIRE',
#     'author': 'David Baldacci',
#     'contributor': 'by David Baldacci',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781538761465.jpg',
#     'book_image_width': 331,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1538761467?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1538761467', 'isbn13': '9781538761465'},
#      {'isbn10': '1538752115', 'isbn13': '9781538752111'},
#      {'isbn10': '1538761505', 'isbn13': '9781538761502'},
#      {'isbn10': '1478999268', 'isbn13': '9781478999263'},
#      {'isbn10': '1549127993', 'isbn13': '9781549127991'},
#      {'isbn10': '1478999276', 'isbn13': '9781478999270'},
#      {'isbn10': '1549127985', 'isbn13': '9781549127984'},
#      {'isbn10': '1549104985', 'isbn13': '9781549104985'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1538761467?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=WALK+THE+WIRE&author=David+Baldacci'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781538761465'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FWALK%2BTHE%2BWIRE%2FDavid%2BBaldacci%2F9781538761465'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781538761465'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781538761465?aff=NYT'}],
#     'book_uri': 'nyt://book/2a73eed3-9d66-53bb-8362-3f0a6bf5b03e'},
#    {'rank': 12,
#     'rank_last_week': 9,
#     'weeks_on_list': 6,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1501133519',
#     'primary_isbn13': '9781501133510',
#     'publisher': 'Atria',
#     'description': 'Daphne Berg’s former best friend asks her to be the maid of honor at her wedding in Cape Cod.',
#     'price': 0,
#     'title': 'BIG SUMMER',
#     'author': 'Jennifer Weiner',
#     'contributor': 'by Jennifer Weiner',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781501133510.jpg',
#     'book_image_width': 331,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/1501133519?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1501133519', 'isbn13': '9781501133510'},
#      {'isbn10': '1797108395', 'isbn13': '9781797108391'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/1501133519?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=BIG+SUMMER&author=Jennifer+Weiner'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781501133510'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FBIG%2BSUMMER%2FJennifer%2BWeiner%2F9781501133510'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781501133510'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781501133510?aff=NYT'}],
#     'book_uri': 'nyt://book/71a12b08-95ae-5898-8855-5f1fb1b31ace'},
#    {'rank': 13,
#     'rank_last_week': 11,
#     'weeks_on_list': 21,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1250209765',
#     'primary_isbn13': '9781250209764',
#     'publisher': 'Flatiron',
#     'description': 'A bookseller flees Mexico for the United States with her son while pursued by the head of a drug cartel.',
#     'price': 0,
#     'title': 'AMERICAN DIRT',
#     'author': 'Jeanine Cummins',
#     'contributor': 'by Jeanine Cummins',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781250209764.jpg',
#     'book_image_width': 326,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/American-Dirt-Oprahs-Book-Club/dp/1250209765?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': 'https://www.nytimes.com/2020/01/17/books/review-american-dirt-jeanine-cummins.html',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1250209765', 'isbn13': '9781250209764'},
#      {'isbn10': '1250772400', 'isbn13': '9781250772404'},
#      {'isbn10': '1432872249', 'isbn13': '9781432872243'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/American-Dirt-Oprahs-Book-Club/dp/1250209765?tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=AMERICAN+DIRT&author=Jeanine+Cummins'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250209764'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FAMERICAN%2BDIRT%2FJeanine%2BCummins%2F9781250209764'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781250209764'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9781250209764?aff=NYT'}],
#     'book_uri': 'nyt://book/ea1c7a1f-1743-57a8-b210-0150f87a4b47'},
#    {'rank': 14,
#     'rank_last_week': 5,
#     'weeks_on_list': 2,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0399178953',
#     'primary_isbn13': '9780399178955',
#     'publisher': 'Ballantine',
#     'description': 'When the new man in her life disappears on 9/11, the budding reporter Cecily Gardner questions what she knew about him.',
#     'price': 0,
#     'title': 'THE LIES THAT BIND',
#     'author': 'Emily Giffin',
#     'contributor': 'by Emily Giffin',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780399178955.jpg',
#     'book_image_width': 336,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/0399178953?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0399178953', 'isbn13': '9780399178955'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0399178953?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+LIES+THAT+BIND&author=Emily+Giffin'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780399178955'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BLIES%2BTHAT%2BBIND%2FEmily%2BGiffin%2F9780399178955'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780399178955'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780399178955?aff=NYT'}],
#     'book_uri': 'nyt://book/8c8d6271-cc73-5e46-bbda-d3d4cce3c6a6'},
#    {'rank': 15,
#     'rank_last_week': 0,
#     'weeks_on_list': 1,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '052547935X',
#     'primary_isbn13': '9780525479352',
#     'publisher': 'Random House',
#     'description': 'The story of four generations of an Ohio family brings to life the tribulations encountered and bonds formed by women in the 20th century.',
#     'price': 0,
#     'title': 'THE DAUGHTERS OF ERIETOWN',
#     'author': 'Connie Schultz',
#     'contributor': 'by Connie Schultz',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780525479352.jpg',
#     'book_image_width': 329,
#     'book_image_height': 500,
#     'amazon_product_url': 'https://www.amazon.com/dp/052547935X?tag=NYTBSREV-20&tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '052547935X', 'isbn13': '9780525479352'}],
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/052547935X?tag=NYTBSREV-20&tag=NYTBS-20'},
#      {'name': 'Apple Books',
#       'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+DAUGHTERS+OF+ERIETOWN&author=Connie+Schultz'},
#      {'name': 'Barnes and Noble',
#       'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780525479352'},
#      {'name': 'Books-A-Million',
#       'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BDAUGHTERS%2BOF%2BERIETOWN%2FConnie%2BSchultz%2F9780525479352'},
#      {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780525479352'},
#      {'name': 'Indiebound',
#       'url': 'https://www.indiebound.org/book/9780525479352?aff=NYT'}],
#     'book_uri': 'nyt://book/250ca3d0-67e1-52d5-81bf-f9f473278c81'}],
#   'corrections': []}}

# %%
url = "https://api.nytimes.com/"
res = requests.get(url)
res
# Out:
# <Response [404]>
